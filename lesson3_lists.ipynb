# %%
friend = 'andre'
# Out:
# 'andre'

# %%
father = 'Dami'

# %%
name = 'i dont know'

# %%
bro = 'bruhhhh'

# %%
msg = 'hey we have a party tonight'

# %%
msg = msg.replace('e','$')
# msg.replace('tophwav'#@%^&()*)
msg.replace('a','#').replace('h','%').replace('o','*')
# Out:
# '%$y w$ %#v$ # p#rty t*nig%t'

# %%
fruits = [ 'banana','apple','watermelon', 'orange'  ]

# %%
print('adam '*100000)
# Out:
# adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam adam ada
# ...

# %%
00
